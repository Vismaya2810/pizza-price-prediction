# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load Dataset
df = pd.read_csv("pizza.csv")
print(df)
# Out:
#    Diameter  Price
# 0         6      7
# 1         8      9
# 2        10     13
# 3        14     17
# 4        18     20

# %%
# Separate Inputs and Outputs
X = df[['Diameter']]
y = df['Price']

# %%
# Create Linear Regression Model
model = LinearRegression()

# %%
# Train the Model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Make Prediction
new_data = pd.DataFrame({'Diameter': [12]})

predicted_price = model.predict(new_data)

print("Diameter:", new_data['Diameter'][0])
print("Predicted Price:", predicted_price[0])
# Out:
# Diameter: 12
# Predicted Price: 14.086206896551724

# %%
# Visualize the Data
plt.scatter(X,y)
plt.plot(X,model.predict(X))

plt.xlabel("Diameter")
plt.ylabel("Price")
plt.title("Pizza Price Prediction")

plt.show()

# %%
# Slope and Intercept
print("Slope:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Slope: [1.10775862]
# Intercept: 0.7931034482758665
